# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
with open('example.txt') as f:
    lines = f.readlines()

# %%
mat=np.zeros((681,681))
for l in lines:
    spl=l.split()
    mat[int(spl[0])][int(spl[1])]=1

# %%
plt.imshow(mat,cmap='gray')
